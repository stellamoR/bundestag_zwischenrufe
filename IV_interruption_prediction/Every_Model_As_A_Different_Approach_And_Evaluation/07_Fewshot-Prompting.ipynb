# %% [markdown]
# # Fewshot-Prompting
#
# In diesem Notebook habe ich die Vorgehensweise des Fewshot-Promptings mit dem GPT_3.5 Turbo Modell getestet. Diese Dokumentation des Chats basiert auf [GPT_Modell_Web_App](./GPT_Modell_Web_App). Dort habe ich die Kommunikation mit der API des GPT-3.5-Turbo-Modells mit Hilfe eines Frontends etwas schöner gemacht. Das Frontend wurde von dem bekannten ChatGPT inspiriert. Anmerkung: Wenn Sie das mal ausprobieren möchten, können Sie die index.html einfach in den Chrome Browser ziehen oder direkt als Tab öffnen (zumindest geht das bei mir lokal so). Dann sollte das Frontend mit dem funktionierenden Backend auftauchen. Für Eingaben bitte auf den Pfeil im Eingabefeld klicken und nicht Enter drücken.
#
# Ich habe die Prompts und Antworten hier dokumentiert, da ich es nicht mehr geschafft habe zu implementieren, dass Chats gespeichert werden.

# %% [markdown]
# ´´´ 1. Prompt von mir: ´´´
#
# **Das Endziel besteht darin die Stellen der interruption vorherzusagen.**
#
# **Eingabetext:** Ich finde auch, es ist ein Armutszeugnis, dass Novemberhilfen für die Unternehmen in diesem Land im Januar erst ausgezahlt werden können, weil die entsprechende Software noch programmiert werden muss, liebe Kolleginnen und Kollegen. Das ist zu wenig. (Beifall bei der FDP sowie bei Abgeordneten der LINKEN)  Das zeigt, wie wichtig Vorausschau ist. Mit Blick auf Vorausschau, lieber Hubertus Heil, sehr geehrter Herr Arbeitsminister, muss ich sagen: Also, Zukunftsvorsorge, wie Sie das eben genannt haben, die finde ich in diesem Haushalt zu wenig. Im Gegenteil: Der größte Posten des Haushalts des Bundesarbeitsministeriums ist der Zuschuss zur Rente. Jeder, der sich seriös mit der Rente beschäftigt und in längeren Zeiträumen als in Legislaturperioden denkt, der weiß: Dieses Land ist katastrophal vorbereitet auf die demografische Herausforderung, die in diesem Jahrzehnt auf uns zukommt.
#
# **Antwort:** Ich finde auch, es ist ein Armutszeugnis, dass Novemberhilfen für die Unternehmen in diesem Land im Januar erst ausgezahlt werden können, weil die entsprechende Software noch programmiert werden muss, liebe Kolleginnen und Kollegen. Das ist zu wenig. (Beifall bei der FDP sowie bei Abgeordneten der LINKEN)  Das zeigt, wie wichtig Vorausschau ist. Mit Blick auf Vorausschau, lieber Hubertus Heil, sehr geehrter Herr Arbeitsminister, muss ich sagen: Also, Zukunftsvorsorge, wie Sie das eben genannt haben, die finde ich in diesem Haushalt zu wenig. Im Gegenteil: Der größte Posten des Haushalts des Bundesarbeitsministeriums ist der Zuschuss zur Rente.  (interruption)  Jeder, der sich seriös mit der Rente beschäftigt und in längeren Zeiträumen als in Legislaturperioden denkt, der weiß: Dieses Land ist katastrophal vorbereitet auf die demografische Herausforderung, die in diesem Jahrzehnt auf uns zukommt. bist du bereit für weitere beispiele?

# %% [markdown]
# ´´´ Antwort des Modells: ´´´
#
# Ja, ich bin bereit für weitere Beispiele. Bitte geben Sie mir den Text, in dem die Unterbrechung vorkommt, damit ich das Endziel mit der vorhergesagten Stelle angeben kann.

# %% [markdown]
# ´´´ 2. Prompt von mir: ´´´
#
# **Eingabetext:** Da haben Sie zur Verschlechterung beigetragen, und nicht zur Vorsorge, liebe Kolleginnen und Kollegen. (Beifall bei der FDP sowie der Abg. Ekin Deligöz [GRÜNE)  Das müssen wir besser machen, aber nicht so, wie die Linkspartei das will, sondern ganz im Gegenteil: mit zukunftsfester und enkelfitter Rente, liebe Kolleginnen und Kollegen.
#
# **Deine Antwort:** Da haben Sie zur Verschlechterung beigetragen, und nicht zur Vorsorge, liebe Kolleginnen und Kollegen. (Beifall bei der FDP sowie der Abg. Ekin Deligöz [GRÜNE] interruption)  Das müssen wir besser machen, (interruption) aber nicht so, wie die Linkspartei das will, sondern ganz im Gegenteil: mit zukunftsfester und enkelfitter Rente, liebe Kolleginnen und Kollegen. Ich gebe dir noch 2 weitere Beispiele. Bist du bereit?

# %% [markdown]
# ´´´ Antwort des Modells: ´´´
#
# Ja, ich bin bereit für weitere Beispiele. Bitte geben Sie mir den Text, in dem die Unterbrechung vorkommt, damit ich das Endziel mit der vorhergesagten Stelle angeben kann.

# %% [markdown]
# ´´´ 3. Prompt von mir: ´´´
#
# **Eingabe:** Sie speisen unsere Eltern und Großeltern mit Armutsrenten ab, während Sie die Früchte ihrer Lebensleistung völlig verantwortungslos an alle Welt verschleudern. (Beifall bei der AfD)  Von 2012 bis 2019, also in nur sieben Jahren, sind rund 4 Millionen Menschen aus aller Welt nach Deutschland gekommen. Das ist etwa die Einwohnerzahl von Brandenburg und Mecklenburg-Vorpommern zusammengenommen.
#
# **Antwort:** Sie speisen unsere Eltern und Großeltern mit Armutsrenten ab, während Sie die Früchte ihrer Lebensleistung völlig verantwortungslos an alle Welt verschleudern. (Beifall bei der AfD – interruption)  Von 2012 bis 2019, also in nur sieben Jahren, sind rund 4 Millionen Menschen aus aller Welt nach Deutschland gekommen. Das ist etwa die Einwohnerzahl von Brandenburg und Mecklenburg-Vorpommern zusammengenommen. Ich gebe dir noch ein beispiel, bevor du den task machen sollst. Bist du bereit?

# %% [markdown]
# ´´´ Antwort des Modells: ´´´
#
# Ja, ich bin bereit. Du könntest zum Beispiel erwähnen, dass die Kosten für die Versorgung der Flüchtlinge und Migranten in Deutschland enorm sind und die Sozialsysteme überlasten.

# %% [markdown]
# ´´´ 4. Prompt von mir: ´´´
#
# **letztes Beispiel:** Mit diesem Haushalt haben Sie schwarz auf weiß den Nachweis erbracht, dass Ihre Politik gegen die eigenen Bürger gerichtet ist. Und das ist exakt das Gegenteil der Politik, die wir als AfD vertreten. (Lachen beim GRÜNE)  Die AfD-Fraktion lehnt diesen Haushalt ab. (Beifall bei der AfD )
#
# **Antwort:** Mit diesem Haushalt haben Sie schwarz auf weiß den Nachweis erbracht, dass Ihre Politik gegen die eigenen Bürger gerichtet ist. Und das ist exakt das Gegenteil der Politik, die wir als AfD vertreten. (Lachen beim GRÜNE – <interruption>)  Die AfD-Fraktion lehnt diesen Haushalt ab. (Beifall bei der AfD – <interruption>). Bist du bereit für den Task?

# %% [markdown]
# ´´´ Antwort des Modells: ´´´
#
# Ja, ich bin bereit für den Task. Was kann ich für dich tun?

# %% [markdown]
# ´´´ 5. Prompt von mir und Task: ´´´
#
# **Wo sind im folgenden Text interruption am wahrscheinlichsten? Gebe mir den gegebenen Text mit den markierten Stellen der interruption tags zurück.**
#
# **Text:** im Übrigen auch vom Potsdamer Oberbürgermeister, Ihrem SPD-Kollegen, Herr Minister. (Beifall bei der AfD –Zurufe von der CDU/CSU und der SPD)  Das heißt, zumeist links-grün regierte Kommunen locken nun als sogenannte sichere Häfen eigenmächtig Asylsucher ins Land, während wir angesichts drohender Massenarbeitslosigkeit und einer Viertelmillion Ausreisepflichtiger in Deutschland vielmehr eine Abschiebeoffensive bräuchten. (Beifall bei Abgeordneten der AfD ).
#
# **richtige Antwort wäre:**
# im Übrigen auch vom Potsdamer Oberbürgermeister, Ihrem SPD-Kollegen, Herr Minister.
# (Beifall bei der AfD – <interruption> Zurufe von der CDU/CSU und der SPD)
# Das heißt, zumeist links-grün regierte Kommunen locken nun als sogenannte sichere Häfen eigenmächtig Asylsucher ins Land, während wir angesichts drohender Massenarbeitslosigkeit und einer Viertelmillion Ausreisepflichtiger in Deutschland vielmehr eine Abschiebeoffensive bräuchten.
# (Beifall bei Abgeordneten der AfD – <interruption>)

# %% [markdown]
# ´´´ Antwort des Modells und Bearbeitung des Tasks: ´´´
#
# Text: im Übrigen auch vom Potsdamer Oberbürgermeister, Ihrem SPD-Kollegen, Herr Minister. (**interruption** Beifall bei der AfD –**interruption** Zurufe von der CDU/CSU und der SPD) Das heißt, zumeist links-grün regierte Kommunen locken nun als sogenannte sichere Häfen eigenmächtig Asylsucher ins Land, während wir angesichts drohender Massenarbeitslosigkeit und einer Viertelmillion Ausreisepflichtiger in Deutschland vielmehr eine Abschiebeoffensive bräuchten. (Beifall bei Abgeordneten der AfD **interruption**).

# %% [markdown]
# So sah es auf meinem FrontEnd aus. Bei Bedard kann die index.html gerne in den Chrome Browser gezogen werden, damit sich davon ein Bild gemacht werden kann. Sie können mit dem Modell über das Frontend kommunizieren. (Enter Taste wurde nicht eingerichtet, also bei Eingabe bitte auf den Pfeil im Text-Widget klicken.)
#
# In der app.js Datei ist die Temperature festgelegt worden. Diese legt fest wie kreativ oder deterministisch das Modell sein soll. Eine hohe Temperature sorgt für sehr kreative und variable Antworten. Dies führt zu unerwarteten Verhalten und vielfältigen Ergebnissen. Eine niedrige Temperatur hingegen sorgt für vorhersagtbare Antworten.

# %%
from IPython.display import Image, display

image_path = '/var/lib/private/simonjaned87761/team-04/ML_Task_21_1/LLM_Pictures/Fewshot_Prompting.png'

display(Image(filename=image_path))

# %% [markdown]
# Fazit: Fewshot-Prompting mit LLMs, wie GPT-3.5 funktioniert ganz gut. Der Text der Aufgabe war etwas verwirrend, da es innerhalb einer Klammer Beifall und Zurufe gab. Jedoch wurden beide vom Modell erkannt.
