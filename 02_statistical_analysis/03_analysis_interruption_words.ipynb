# %%
import pandas as pd
from collections import Counter
import nltk
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re
import seaborn as sns
pd.set_option('chained_assignment',None)

# %%
parties = ['CDU/CSU', 'SPD','GRÜNE', 'FDP', 'AfD', 'DIE LINKE', 'fraktionslos']

# %%
df_interruptions = pd.read_csv('./data/comments.csv')
df_interruptions.head(10)
# Out:
#    Unnamed: 0                                       comment_text  \
# 0           0  So kriegen Sie  die Steuerlüge nicht aus der W...
# 1           1                                             Bravo!
# 2           2                    Das ist doch die  erste Lesung!
# 3           3                           Das ist eine  Frechheit!
# 4           4  Gebt erst  mal das Vermögen der PDS dem Staat ...
# 5           5            Die PDS  soll das Vermögen zurückgeben!
# 6           6                                  Wundert Sie  das?
# 7           7  Der muß auch  noch reden? Reicht denn nicht ei...
# 8           8                                     Das sagen Sie!
# 9           9                                         Wohl wahr!
#
#   comment_party         comment_name interrupted_speaker_party  \
# 0     DIE LINKE          Dr. B riefs                   CDU/CSU
# 1           SPD            <unknown>                   CDU/CSU
# 2       CDU/CSU            <unknown>                 DIE LINKE
# 3     DIE LINKE            <unknown>                   CDU/CSU
# 4       CDU/CSU           zu Bentrup                 DIE LINKE
# 5       CDU/CSU           zu Bentrup                 DIE LINKE
# 6       CDU/CSU            <unknown>                 DIE LINKE
# 7       CDU/CSU            <unknown>                 DIE LINKE
# 8       CDU/CSU            <unknown>                 DIE LINKE
# 9           FDP  Dr. Graf Lambsdorff                       FDP
#
#    interrupted_speaker        date  speech_len_sents  speech_id
# 0   Dr. Theodor Waigel  1991-03-12               386          1
# 1   Dr. Theodor Waigel  1991-03-12               386          1
# 2     Dr. Barbara Höll  1991-03-12                11          2
# 3  Dr. Jürgen Rüttgers  1991-03-12                15          3
# 4    Dr. Ulrich Briefs  1991-03-12               127          7
# 5    Dr. Ulrich Briefs  1991-03-12               127          7
# 6    Dr. Ulrich Briefs  1991-03-12               127          7
# 7    Dr. Ulrich Briefs  1991-03-12               127          7
# 8    Dr. Ulrich Briefs  1991-03-12               127          7
# 9    Dr. Wolfgang Weng  1991-03-12               180          8

# %% [markdown]
# Einige (wenige) Felder sind leider leer aus den Protokollen geparst worden. Die nehmen wir jetzt heraus.

# %%
non_string_entries = df_interruptions['comment_text'].apply(lambda x: not isinstance(x, str))
df_interruptions[non_string_entries]
# Out:
#         Unnamed: 0 comment_text comment_party           comment_name  \
# 12513        12513          NaN       CDU/CSU              <unknown>
# 16615        16615          NaN       CDU/CSU      Bartholomäus Kalb
# 40594        40594          NaN           FDP           Ulrich Irmer
# 45906        45906          NaN           FDP         Dr. Klaus Röhl
# 80506        80506          NaN       CDU/CSU           Norbert Geis
# 80593        80593          NaN           SPD        Ludwig Stiegler
# 83273        83273          NaN           FDP  Hans-Michael Goldmann
# 330343      330343          NaN           FDP      Benjamin Strasser
# 385456      385456          NaN           AfD          Marc Bernhard
# 407540      407540          NaN           AfD             Jörn König
# 412283      412283          NaN     DIE LINKE        Dr. Petra Sitte
# 443122      443122          NaN       CDU/CSU         Steffen Bilger
# 444310      444310          NaN           AfD             Jörn König
# 450918      450918          NaN       CDU/CSU       Dr. Klaus Wiener
#
#        interrupted_speaker_party   interrupted_speaker        date  \
# 12513                        SPD      Jan Oostergetelo  1992-06-24
# 16615                    CDU/CSU         Manfred Kolbe  1992-11-26
# 40594                      GRÜNE    Dr. Helmut Lippelt  1995-09-29
# 45906                        SPD      Ursula Burchardt  1996-04-24
# 80506                        SPD     Hermann Bachmaier  2000-03-23
# 80593                    CDU/CSU   Dr. Norbert Lammert  2000-03-24
# 83273                        FDP           Marita Sehn  2000-06-29
# 330343                       SPD  Dr. Lars Castellucci  2017-12-13
# 385456                       AfD         Marc Bernhard  2020-11-26
# 407540                       AfD            Jörn König  2022-06-23
# 412283                       SPD            Simona Koß  2022-09-23
# 443122                       SPD        Esther Dilcher  2023-09-07
# 444310                       FDP  Maximilian Mordhorst  2023-09-21
# 450918                       SPD       Dr. Nina Scheer  2023-11-10
#
#         speech_len_sents  speech_id
# 12513                 75       8693
# 16615                 87      11511
# 40594                 26      30080
# 45906                 38      34213
# 80506                 33      54995
# 80593                 58      55017
# 83273                 33      56237
# 330343                50     163566
# 385456                34     190990
# 407540                39     203838
# 412283                37     205405
# 443122                50     215418
# 444310                56     215847
# 450918                69     218167

# %%
df_interruptions= df_interruptions[~non_string_entries]

# %%
texts_per_party = df_interruptions.groupby('comment_party')['comment_text'].apply(lambda x: ' '.join(x))

# %%
texts_per_party
# Out:
# comment_party
# AfD             Ha, ha, ha! Das ist nicht unser Problem! Ui, d...
# CDU/CSU         Das ist doch die  erste Lesung! Gebt erst  mal...
# DIE LINKE       So kriegen Sie  die Steuerlüge nicht aus der W...
# FDP             Wohl wahr! Verfassungswidrig! Unfug! Wofür  so...
# GRÜNE           Das ist Rea  Sie fielen gestern im Plenum! Wah...
# SPD             Bravo! Haben Sie vergessen  hinzuschauen? Sind...
# fraktionslos    Bei Wechsel  der Verhältnisse! Er ist trotz de...
# Name: comment_text, dtype: object

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Robin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokenizer = nltk.data.load("tokenizers/punkt/german.pickle")

# %%
def get_ngrams(text, n):
    tokens = word_tokenize(text, language = 'german')
    return list(ngrams(tokens, n))

ngrams_data = {}
for party, text in texts_per_party.items():
    print(party)
    unigrams = get_ngrams(text, 1)
    bigrams = get_ngrams(text, 2)
    trigrams = get_ngrams(text, 3)
    
    ngrams_data[party] = {
        'unigrams': Counter(unigrams),
        'bigrams': Counter(bigrams),
        'trigrams': Counter(trigrams)
    }
# Out:
# AfD
# CDU/CSU
# DIE LINKE
# FDP
# GRÜNE
# SPD
# fraktionslos

# %%
df_interruptions.loc[df_interruptions['comment_text'].str.contains('ichglaubejedenscheiss.de', na=False)]
# Out:
#         Unnamed: 0                   comment_text comment_party  \
# 462772      462772  www.ichglaubejedenscheiss.de!           AfD
#
#             comment_name interrupted_speaker_party interrupted_speaker  \
# 462772  Martin Reichardt                       SPD    Josephine Ortleb
#
#               date  speech_len_sents  speech_id
# 462772  2024-03-15                34     221700

# %%
df_interruptions.loc[df_interruptions['comment_text'].str.contains('Naturschutzzerstörungsfraktion', na=False)]
# Out:
#         Unnamed: 0                                  comment_text  \
# 394229      394229  Die Naturschutzzerstörungsfraktion seid ihr!
#
#        comment_party   comment_name interrupted_speaker_party  \
# 394229           AfD  Karsten Hilse                     GRÜNE
#
#        interrupted_speaker        date  speech_len_sents  speech_id
# 394229        Steffi Lemke  2021-05-20                37     196876

# %%
df_interruptions.loc[df_interruptions['comment_text'].str.contains('Verschwörungstheoretiker', na=False)]
# Out:
#         Unnamed: 0                                       comment_text  \
# 312819      312819                    Alles Verschwörungstheoretiker!
# 337842      337842             Von anderen Verschwörungstheoretikern!
# 347197      347197                          Verschwörungstheoretiker!
# 348183      348183  Die Krise ist ja nicht weg! Verschwörungstheor...
# 354722      354722                          Verschwörungstheoretiker!
# 374943      374943                          Verschwörungstheoretiker!
# 374995      374995  So ein Quatsch! Verschwörungstheoretiker! Setz...
# 377094      377094  Sie laufen ja lieber bei Verschwörungstheoreti...
# 379039      379039  Uns als Verschwörungstheoretiker zu bezeichnen...
# 393887      393887           Das sagen alle Verschwörungstheoretiker!
# 399510      399510             Sie sind ein Verschwörungstheoretiker!
# 400695      400695                          Verschwörungstheoretiker!
#
#        comment_party        comment_name interrupted_speaker_party  \
# 312819         GRÜNE  Sylvia Kotting-Uhl                       SPD
# 337842           FDP    Konstantin Kuhle                       AfD
# 347197           SPD           <unknown>                       AfD
# 348183           AfD      Leif-Erik Holm                       SPD
# 354722           AfD      Jörg Schneider                       FDP
# 374943           AfD    Stephan Brandner                   CDU/CSU
# 374995       CDU/CSU          Tino Sorge                       AfD
# 377094           SPD      Timon Gremmels                       AfD
# 379039     DIE LINKE        Evrim Sommer                       FDP
# 393887           AfD   Elsner von Gronow                       SPD
# 399510           AfD       René Springer                   CDU/CSU
# 400695           SPD      Timon Gremmels                       AfD
#
#            interrupted_speaker        date  speech_len_sents  speech_id
# 312819           Klaus Barthel  2016-05-11                77     154789
# 337842        Stephan Brandner  2018-06-14                50     167757
# 347197     Armin-Paulus Hampel  2018-11-30                51     171932
# 348183          Metin Hakverdi  2018-12-13                61     172354
# 354722        Konstantin Kuhle  2019-04-05                17     175663
# 374943          Philipp Amthor  2020-05-07                91     185103
# 374995      Detlev Spangenberg  2020-05-07                70     185120
# 377094           Andreas Bleck  2020-05-29                44     186228
# 379039           Ulrich Lechte  2020-07-03                42     187388
# 393887  Dr. Karl-Heinz Brunner  2021-05-07                40     196557
# 399510            Knut Abraham  2022-02-18                51     200145
# 400695         Wolfgang Wiehle  2022-03-22                47     200728

# %%
df_interruptions.loc[df_interruptions['comment_text'].str.contains('Landschaftsverschandelung', na=False)]
# Out:
#         Unnamed: 0                        comment_text comment_party  \
# 381621      381621  Landschaftsverschandelung ist das!           AfD
#
#              comment_name interrupted_speaker_party interrupted_speaker  \
# 381621  Dr. Götz Frömming                       SPD       Yasmin Fahimi
#
#               date  speech_len_sents  speech_id
# 381621  2020-10-01                45     188708

# %%
df_interruptions.loc[df_interruptions['comment_text'].apply(lambda x: bool(re.search(r'.*\.de.*|.*\.com.*|www\..*', str(x), flags= re.UNICODE|re.IGNORECASE)))]
# Out:
#         Unnamed: 0                         comment_text comment_party  \
# 325556      325556  Ich empfehle www.linksfraktion.de !     DIE LINKE
# 462772      462772        www.ichglaubejedenscheiss.de!           AfD
# 463355      463355                         chefkoch.de!           AfD
# 463379      463379                         chefkoch.de!           AfD
# 463380      463380                     Für chefkoch.de!           AfD
# 463381      463381                         chefkoch.de!           AfD
#
#                 comment_name interrupted_speaker_party  \
# 325556  Matthias W. Birkwald                       SPD
# 462772      Martin Reichardt                       SPD
# 463355    Beatrix von Storch                       SPD
# 463379    Beatrix von Storch                       FDP
# 463380    Beatrix von Storch                       FDP
# 463381    Beatrix von Storch                       FDP
#
#             interrupted_speaker        date  speech_len_sents  speech_id
# 325556         Mechthild Rawert  2017-03-31                57     161180
# 462772         Josephine Ortleb  2024-03-15                34     221700
# 463355      Dr. Jens Zimmermann  2024-03-21                51     221980
# 463379  Maximilian Funke-Kaiser  2024-03-21                 8     221987
# 463380  Maximilian Funke-Kaiser  2024-03-21                 8     221987
# 463381  Maximilian Funke-Kaiser  2024-03-21                 8     221987

# %%
df_interruptions.loc[df_interruptions['comment_text'].apply(lambda x: bool(re.search(r'.*Zwischenruf.*', str(x), flags= re.UNICODE|re.IGNORECASE)))]
# Out:
#         Unnamed: 0                                       comment_text  \
# 417            417                   Aber  Zwischenrufe sind erlaubt!
# 1457          1457  „Uns ken nen alle" war der Zwischenruf des Kol...
# 1631          1631                       Der Zwischenruf des  Jahres!
# 3740          3740                                  Zwischenrufe nie!
# 4141          4141  Das war keine Frage,  das war nur ein Zwischen...
# ...            ...                                                ...
# 449999      449999                        Zwischenrufe sind zulässig!
# 456396      456396  Das zeigt mal wieder, wo Sie hängen geblieben ...
# 458880      458880  Das ist so unterkomplex, da kann man nicht in ...
# 462243      462243  Da wäre der Zwischenruf „Fake News“ noch ein E...
# 465270      465270  Genau! Das muss  mal geahndet werden hier! Es ...
#
#        comment_party        comment_name interrupted_speaker_party  \
# 417          CDU/CSU   Gerhard Reddemann                       SPD
# 1457         CDU/CSU   Bartholomäus Kalb                   CDU/CSU
# 1631             SPD        fried Penner                       FDP
# 3740             SPD         Gerd Andres                   CDU/CSU
# 4141             SPD       Peter Conradi                       SPD
# ...              ...                 ...                       ...
# 449999           AfD      Enrico Komning                     GRÜNE
# 456396         GRÜNE  Tobias B. Bacherle                       AfD
# 458880           SPD    Dr. Wiebke Esdar                   CDU/CSU
# 462243           SPD  Sebastian Hartmann                   CDU/CSU
# 465270           AfD    Stephan Brandner                       AfD
#
#         interrupted_speaker        date  speech_len_sents  speech_id
# 417     Dr. Wilfried Penner  1991-04-18                 8        720
# 1457      Irmgard Karwatzki  1991-06-04                58       1383
# 1631           Ina Albowitz  1991-06-05               133       1456
# 3740        Arnulf Kriedner  1991-09-05                76       2673
# 4141             Dorle Marx  1991-09-19                 7       2913
# ...                     ...         ...               ...        ...
# 449999     Dr. Till Steffen  2023-11-09                38     217960
# 456396  Dr. Gottfried Curio  2023-12-15                61     219778
# 458880     Thomas Jarzombek  2024-01-30                60     220446
# 462243      Andrea Lindholz  2024-03-14                86     221564
# 465270         Jürgen Braun  2024-04-11                51     222546
#
# [191 rows x 9 columns]

# %% [markdown]
# Da fallen einem schon keine Zwischenrufe mehr ein, so absurd ist das!

# %%
df_interruptions.loc[df_interruptions['comment_text'].apply(lambda x: bool(re.search(r'.*Das ist viel zu billig.*', str(x), flags= re.UNICODE|re.IGNORECASE)))]
# Out:
#         Unnamed: 0                                       comment_text  \
# 150059      150059  Das ist viel zu billig! So billig sind Sie doc...
#
#        comment_party  comment_name interrupted_speaker_party  \
# 150059       CDU/CSU  Michael Glos                       SPD
#
#        interrupted_speaker        date  speech_len_sents  speech_id
# 150059    Gerhard Schröder  2004-11-24               354      78957

# %%
df_interruptions.loc[df_interruptions['comment_text'].apply(lambda x: bool(re.search(r'.*Die Sendung mit der Maus.*', str(x), flags= re.UNICODE|re.IGNORECASE)))]
# Out:
#         Unnamed: 0                                       comment_text  \
# 370500      370500                        „Die Sendung mit der Maus“!
# 422942      422942  Ja, das ist genau Ihr intellektuelles Niveau: ...
#
#        comment_party       comment_name interrupted_speaker_party  \
# 370500       CDU/CSU  Dr. Georg Nüßlein                 DIE LINKE
# 422942           AfD   Martin Reichardt                 DIE LINKE
#
#        interrupted_speaker        date  speech_len_sents  speech_id
# 370500        Gösta Beutin  2020-01-17                62     182652
# 422942    Heidi Reichinnek  2022-12-15                34     208680

# %%
for party, ngram_counts in ngrams_data.items():
    print(f"Partei: {party}")
    print(f"Häufigste unigramme:{ ngram_counts['unigrams'].most_common(10)}")
    print(f"Häufigste bigramme: {ngram_counts['bigrams'].most_common(10)}")
    print(f"Häufigste trigramme: {ngram_counts['trigrams'].most_common(10)}")
    print()
# Out:
# Partei: AfD
# Häufigste unigramme:[(('!',), 33654), (('Sie',), 8531), ((',',), 6733), (('Das',), 5536), (('?',), 4637), (('ist',), 4540), (('nicht',), 4000), (('die',), 3505), (('das',), 2946), (('doch',), 2784)]
# Häufigste bigramme: [(('!', 'Das'), 4818), (('Das', 'ist'), 2263), (('!', 'Sie'), 2234), (('!', 'Die'), 1277), (('nicht', '!'), 1201), (('!', 'Ja'), 1016), (('!', 'Was'), 836), (('Ja', ','), 791), (('!', 'Wir'), 719), ((',', 'Herr'), 716)]
# Häufigste trigramme: [(('!', 'Das', 'ist'), 1964), (('!', 'Ja', ','), 694), (('!', 'Sie', 'haben'), 514), (('!', 'Hört', '!'), 426), (('Das', 'ist', 'doch'), 393), (('!', 'Genau', '!'), 370), (('!', 'Ja', '!'), 307), (('!', 'Sie', 'sind'), 279), (('?', 'Das', 'ist'), 252), (('!', 'Das', 'war'), 249)]
#
# Partei: CDU/CSU
# Häufigste unigramme:[(('!',), 135905), (('Sie',), 27237), (('Das',), 26362), (('ist',), 24485), ((',',), 23828), (('nicht',), 17841), (('?',), 17677), (('die',), 13045), (('das',), 12181), (('doch',), 12041)]
# Häufigste bigramme: [(('!', 'Das'), 22763), (('Das', 'ist'), 11093), (('!', 'Sie'), 6510), (('nicht', '!'), 5192), (('!', 'So'), 5109), (('!', 'Die'), 4196), (('!', 'Sehr'), 4113), (('ist', 'es'), 4109), (('es', '!'), 4073), (('So', 'ist'), 3757)]
# Häufigste trigramme: [(('!', 'Das', 'ist'), 9536), (('ist', 'es', '!'), 3635), (('!', 'So', 'ist'), 3382), (('So', 'ist', 'es'), 3285), (('!', 'Hört', '!'), 2325), (('Das', 'ist', 'doch'), 1836), (('Sehr', 'richtig', '!'), 1777), (('!', 'Sie', 'haben'), 1671), (('!', 'Sehr', 'richtig'), 1621), (('!', 'Ja', ','), 1532)]
#
# Partei: DIE LINKE
# Häufigste unigramme:[(('!',), 40227), (('Das',), 7829), (('Sie',), 7181), ((',',), 6720), (('ist',), 6252), (('nicht',), 5419), (('?',), 5297), (('die',), 4026), (('das',), 3499), (('doch',), 3043)]
# Häufigste bigramme: [(('!', 'Das'), 6822), (('Das', 'ist'), 3203), (('!', 'Sie'), 1692), (('nicht', '!'), 1664), (('!', 'Die'), 1309), (('!', 'Ja'), 1202), (('!', 'Aber'), 970), (('!', 'Was'), 962), (('!', 'Wir'), 923), (('?', 'Das'), 851)]
# Häufigste trigramme: [(('!', 'Das', 'ist'), 2801), (('!', 'Ja', ','), 673), (('!', 'Genau', '!'), 624), (('!', 'Das', 'stimmt'), 500), (('!', 'Ja', '!'), 497), (('!', 'Richtig', '!'), 479), (('Das', 'ist', 'doch'), 471), (('!', 'Sie', 'haben'), 449), (('!', 'Hört', '!'), 438), (('!', 'Das', 'war'), 411)]
#
# Partei: FDP
# Häufigste unigramme:[(('!',), 70387), (('Das',), 14398), (('Sie',), 13594), ((',',), 12997), (('ist',), 12850), (('nicht',), 9663), (('?',), 9455), (('die',), 6976), (('das',), 6927), (('doch',), 6534)]
# Häufigste bigramme: [(('!', 'Das'), 12460), (('Das', 'ist'), 5792), (('!', 'Sie'), 3327), (('nicht', '!'), 2762), (('!', 'So'), 2454), (('!', 'Die'), 2287), (('ist', 'es'), 2182), (('es', '!'), 2136), (('So', 'ist'), 1948), (('!', 'Sehr'), 1846)]
# Häufigste trigramme: [(('!', 'Das', 'ist'), 5039), (('ist', 'es', '!'), 1944), (('So', 'ist', 'es'), 1760), (('!', 'So', 'ist'), 1746), (('!', 'Richtig', '!'), 1051), (('Sehr', 'richtig', '!'), 963), (('Das', 'ist', 'doch'), 962), (('!', 'Sehr', 'richtig'), 885), (('!', 'Sie', 'haben'), 864), (('!', 'Ja', ','), 853)]
#
# Partei: GRÜNE
# Häufigste unigramme:[(('!',), 76194), (('Sie',), 19429), ((',',), 16059), (('Das',), 15640), (('?',), 13551), (('ist',), 13048), (('nicht',), 11878), (('das',), 8482), (('die',), 8143), (('doch',), 7216)]
# Häufigste bigramme: [(('!', 'Das'), 13244), (('Das', 'ist'), 6114), (('!', 'Sie'), 4291), (('nicht', '!'), 3333), (('!', 'Was'), 2509), (('!', 'Die'), 2448), (('!', 'Ja'), 2322), (('?', 'Das'), 2069), (('!', 'Wir'), 1879), (('!', 'Aber'), 1848)]
# Häufigste trigramme: [(('!', 'Das', 'ist'), 5161), (('!', 'Ja', ','), 1309), (('!', 'Sie', 'haben'), 1216), (('Das', 'ist', 'doch'), 1066), (('!', 'Ja', '!'), 963), (('!', 'Das', 'stimmt'), 872), (('!', 'Genau', '!'), 850), (('?', 'Das', 'ist'), 827), (('!', 'Das', 'war'), 802), (('!', 'Nein', '!'), 662)]
#
# Partei: SPD
# Häufigste unigramme:[(('!',), 117909), (('Sie',), 27149), (('Das',), 24138), ((',',), 22451), (('ist',), 20147), (('?',), 17274), (('nicht',), 16132), (('das',), 11547), (('die',), 11486), (('doch',), 11407)]
# Häufigste bigramme: [(('!', 'Das'), 20488), (('Das', 'ist'), 10141), (('!', 'Sie'), 6384), (('nicht', '!'), 4441), (('!', 'Die'), 3557), (('!', 'Was'), 3277), (('?', 'Das'), 2814), (('!', 'So'), 2809), (('!', 'Wir'), 2662), ((',', 'Herr'), 2569)]
# Häufigste trigramme: [(('!', 'Das', 'ist'), 8569), (('Das', 'ist', 'doch'), 1774), (('!', 'Hört', '!'), 1604), (('!', 'Sie', 'haben'), 1571), (('ist', 'es', '!'), 1482), (('!', 'So', 'ist'), 1470), (('So', 'ist', 'es'), 1351), (('!', 'Ja', ','), 1299), (('!', 'Das', 'war'), 1290), (('?', 'Das', 'ist'), 1227)]
#
# Partei: fraktionslos
# Häufigste unigramme:[(('!',), 82), (('Das',), 18), (('Sie',), 15), (('ist',), 13), (('das',), 11), (('nicht',), 11), ((',',), 10), (('die',), 9), (('wahr',), 7), (('ja',), 6)]
# Häufigste bigramme: [(('!', 'Das'), 16), (('Das', 'ist'), 10), (('wahr', '!'), 7), (('!', 'Sie'), 6), (('!', 'Danke'), 5), (('Danke', '!'), 4), (('!', 'Sehr'), 4), (('Sehr', 'wahr'), 4), (('!', 'Die'), 4), (('ist', 'ja'), 3)]
# Häufigste trigramme: [(('!', 'Das', 'ist'), 8), (('!', 'Danke', '!'), 4), (('Sehr', 'wahr', '!'), 4), (('!', 'Sehr', 'wahr'), 3), (('!', 'Unglaublich', '!'), 3), (('Das', 'ist', 'die'), 3), (('!', 'Leider', 'wahr'), 2), (('Leider', 'wahr', '!'), 2), (('Das', 'ist', 'ja'), 2), (('ist', 'ja', 'das'), 2)]

# %% [markdown]
# Anscheinend ist das '!' sehr hoch im Kurs. Wie viel Prozent der Unterbrechungen enthalten denn ein Ausrufezeichen?

# %%
percentage_excl_marks = df_interruptions['comment_text'].apply(lambda x:'!' in x).sum()/len(df_interruptions)*100
print(f"{percentage_excl_marks:.2f} %")
# Out:
# 86.40 %

# %% [markdown]
# Die Kommentatoren wollen sich anscheinend Ausdruck verleihen. Sonst würden sie ja niemanden unterbrechen...

# %% [markdown]
# # Wordclouds

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(texts_per_party['AfD'])

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)

# %% [markdown]
# Jetzt noch mit Stopwords, damit die Ansicht aussagekräftiger wird...

# %%
stopwords = ['Da', 'Sie', 'die', 'Das', 'ist', 'und', 'Dann', 'Wer', 'Wo', 'mit', 'gesagt', 'Was', 'sind', 'denn', 'haben', 'e', 'zu', 'sich', 'Ihre', 'der', 'es', 'So', 'Wie']
wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords).generate(texts_per_party['CDU/CSU'])

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)

# %% [markdown]
# Die Wortfolge Hört Hört ist wohl ziemlich beliebt...

# %%
df_hoert_hoert = df_interruptions[df_interruptions['comment_text'].apply(lambda x: bool(re.search('hört.* hört.*', x, flags= re.UNICODE|re.IGNORECASE)))]
df_hoert_hoert.head(5)
# Out:
#      Unnamed: 0        comment_text comment_party      comment_name  \
# 341         341         Hört! Hört!           SPD         <unknown>
# 413         413         Hört! Hört!       CDU/CSU   Arnulf Kriedner
# 448         448         Hört! Hört!           FDP         <unknown>
# 494         494  Hört! Hört! Da wer           SPD    Dr. Uwe Küster
# 534         534         Hört! Hört!       CDU/CSU  Peter Kittelmann
#
#     interrupted_speaker_party        interrupted_speaker        date  \
# 341                       SPD      Ingrid Matthäus-Maier  1991-04-17
# 413                   CDU/CSU           Dr. Gero Pfennig  1991-04-17
# 448                   CDU/CSU          Dr. Angela Merkel  1991-04-18
# 494                   CDU/CSU  Susanne Rahardt-Vahldieck  1991-04-18
# 534                   CDU/CSU              Horst Eylmann  1991-04-18
#
#      speech_len_sents  speech_id
# 341                48        705
# 413                36        718
# 448                81        742
# 494                65        757
# 534                45        802

# %%
from spacy.lang.de import German
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from spacy.lang.de import German
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\__init__.py:13
#      10 # These are imported as part of the API
#      11 from thinc.api import Config, prefer_gpu, require_cpu, require_gpu  # noqa: F401
# ---> 13 from . import pipeline  # noqa: F401
#      14 from . import util
#      15 from .about import __version__  # noqa: F401
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\pipeline\__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .edit_tree_lemmatizer import EditTreeLemmatizer
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\pipeline\attributeruler.py:8
#       6 from .. import util
#       7 from ..errors import Errors
# ----> 8 from ..language import Language
#       9 from ..matcher import Matcher
#      10 from ..scorer import Scorer
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\language.py:43
#      41 from .lang.tokenizer_exceptions import BASE_EXCEPTIONS, URL_MATCH
#      42 from .lookups import load_lookups
# ---> 43 from .pipe_analysis import analyze_pipes, print_pipe_analysis, validate_attrs
#      44 from .schemas import (
#      45     ConfigSchema,
#      46     ConfigSchemaInit,
#    (...)
#      49     validate_init_settings,
#      50 )
#      51 from .scorer import Scorer
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\pipe_analysis.py:6
#       3 from wasabi import msg
#       5 from .errors import Errors
# ----> 6 from .tokens import Doc, Span, Token
#       7 from .util import dot_to_dict
#       9 if TYPE_CHECKING:
#      10     # This lets us add type hints for mypy etc. without causing circular imports
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\tokens\__init__.py:1
# ----> 1 from ._serialize import DocBin
#       2 from .doc import Doc
#       3 from .morphanalysis import MorphAnalysis
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\tokens\_serialize.py:14
#      12 from ..errors import Errors
#      13 from ..util import SimpleFrozenList, ensure_path
# ---> 14 from ..vocab import Vocab
#      15 from ._dict_proxies import SpanGroups
#      16 from .doc import DOCBIN_ALL_ATTRS as ALL_ATTRS
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\vocab.pyx:1, in init spacy.vocab()
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\tokens\doc.pyx:49, in init spacy.tokens.doc()
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\spacy\schemas.py:195
#     191         obj = converted
#     192     return validate(TokenPatternSchema, {"pattern": obj})
# --> 195 class TokenPatternString(BaseModel):
#     196     REGEX: Optional[Union[StrictStr, "TokenPatternString"]] = Field(None, alias="regex")
#     197     IN: Optional[List[StrictStr]] = Field(None, alias="in")
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\pydantic\v1\main.py:286, in ModelMetaclass.__new__(mcs, name, bases, namespace, **kwargs)
#     284 cls.__signature__ = ClassAttribute('__signature__', generate_model_signature(cls.__init__, fields, config))
#     285 if resolve_forward_refs:
# --> 286     cls.__try_update_forward_refs__()
#     288 # preserve `__set_name__` protocol defined in https://peps.python.org/pep-0487
#     289 # for attributes not in `new_namespace` (e.g. private attributes)
#     290 for name, obj in namespace.items():
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\pydantic\v1\main.py:807, in BaseModel.__try_update_forward_refs__(cls, **localns)
#     801 @classmethod
#     802 def __try_update_forward_refs__(cls, **localns: Any) -> None:
#     803     """
#     804     Same as update_forward_refs but will not raise exception
#     805     when forward references are not defined.
#     806     """
# --> 807     update_model_forward_refs(cls, cls.__fields__.values(), cls.__config__.json_encoders, localns, (NameError,))
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\pydantic\v1\typing.py:554, in update_model_forward_refs(model, fields, json_encoders, localns, exc_to_suppress)
#     552 for f in fields:
#     553     try:
# --> 554         update_field_forward_refs(f, globalns=globalns, localns=localns)
#     555     except exc_to_suppress:
#     556         pass
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\pydantic\v1\typing.py:529, in update_field_forward_refs(field, globalns, localns)
#     527 if field.sub_fields:
#     528     for sub_f in field.sub_fields:
# --> 529         update_field_forward_refs(sub_f, globalns=globalns, localns=localns)
#     531 if field.discriminator_key is not None:
#     532     field.prepare_discriminated_union_sub_fields()
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\pydantic\v1\typing.py:520, in update_field_forward_refs(field, globalns, localns)
#     518 if field.type_.__class__ == ForwardRef:
#     519     prepare = True
# --> 520     field.type_ = evaluate_forwardref(field.type_, globalns, localns or None)
#     521 if field.outer_type_.__class__ == ForwardRef:
#     522     prepare = True
#
# File c:\ProgFiles\PythonVenvs\.NLPvenv\Lib\site-packages\pydantic\v1\typing.py:66, in evaluate_forwardref(type_, globalns, localns)
#      63 def evaluate_forwardref(type_: ForwardRef, globalns: Any, localns: Any) -> Any:
#      64     # Even though it is the right signature for python 3.9, mypy complains with
#      65     # `error: Too many arguments for "_evaluate" of "ForwardRef"` hence the cast...
# ---> 66     return cast(Any, type_)._evaluate(globalns, localns, set())
#
# TypeError: ForwardRef._evaluate() missing 1 required keyword-only argument: 'recursive_guard'
