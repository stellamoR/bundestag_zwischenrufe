# %%
import requests
import pandas as pd
import json

# %%
def dict_to_html_params(data):
    html_params = ""
    for key, value in data.items():
        if value != None:
            html_params += f"&{key}={value}"
    return html_params.strip()

# %%
url_static= "https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF"

params = {
        "f.datum.start": "2000-01-01", # Change here for different Dates
        "f.datum.end": "2000-05-15",
        "f.zuordnung": "BT",
        "cursor" : None
    }

doc_count = 0
while(True):
    
    api_url = url_static + dict_to_html_params(params)
    print(api_url)

    response = requests.get(api_url)
    print(response)

    if response.status_code == 200:

        with open('./data/opendata_api/requestlibrary.json', 'w', encoding='utf-8') as json_file:
            json.dump(response.json(),json_file, indent=4)

        doc_list = response.json()['documents']
        doc_count += len(doc_list)
        for doc in doc_list:
            path = f'./data/opendata_api/{doc['wahlperiode']}_{doc['dokumentnummer'].split(r'/')[1].zfill(3)}_{doc['datum']}.json'
            print(path)
            with open(path, 'w', encoding='utf-8') as json_file:
                json.dump(doc,json_file, indent=4)
    else:
         print("Error in call. Aborting")
         break
    
    if 'cursor' not in response.json():
        print(f"Retrieved all {doc_list}Documents")
        break 
    elif response.json()['cursor']== params['cursor']:
        print(f"Retrieved all {doc_count} Documents")
        break
    else:
        params['cursor'] = response.json()['cursor']
# Out:
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2000-01-01&f.datum.end=2000-05-15&f.zuordnung=BT
# <Response [200]>
# ./data/opendata_api/14_103_2000-05-12.json
# ./data/opendata_api/14_102_2000-05-11.json
# ./data/opendata_api/14_101_2000-05-10.json
# ./data/opendata_api/14_100_2000-04-14.json
# ./data/opendata_api/14_099_2000-04-13.json
# ./data/opendata_api/14_098_2000-04-06.json
# ./data/opendata_api/14_097_2000-04-05.json
# ./data/opendata_api/14_096_2000-03-24.json
# ./data/opendata_api/14_095_2000-03-23.json
# ./data/opendata_api/14_094_2000-03-22.json
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2000-01-01&f.datum.end=2000-05-15&f.zuordnung=BT&cursor=AoJw-OCTh94BNFBsZW5hcnByb3Rva29sbC0xMjUw
# <Response [200]>
# ./data/opendata_api/14_093_2000-03-16.json
# ./data/opendata_api/14_092_2000-03-15.json
# ./data/opendata_api/14_091_2000-02-25.json
# ./data/opendata_api/14_090_2000-02-24.json
# ./data/opendata_api/14_089_2000-02-23.json
# ./data/opendata_api/14_088_2000-02-18.json
# ./data/opendata_api/14_087_2000-02-17.json
# ./data/opendata_api/14_086_2000-02-16.json
# ./data/opendata_api/14_085_2000-01-28.json
# ./data/opendata_api/14_001_2000-01-27.json
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2000-01-01&f.datum.end=2000-05-15&f.zuordnung=BT&cursor=AoJwuKjE-dwBNFBsZW5hcnByb3Rva29sbC0zMDk4
# <Response [200]>
# ./data/opendata_api/14_084_2000-01-27.json
# ./data/opendata_api/14_083_2000-01-26.json
# ./data/opendata_api/14_082_2000-01-21.json
# ./data/opendata_api/14_081_2000-01-20.json
# ./data/opendata_api/14_080_2000-01-19.json
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2000-01-01&f.datum.end=2000-05-15&f.zuordnung=BT&cursor=AoJwuMz35NwBNFBsZW5hcnByb3Rva29sbC0xMjU2
# <Response [200]>
# Retrieved all 25 Documents

# %% [markdown]
# Auch die aktuellen Protokolle sind nicht im neueren XML-Format (mit Rede + Kommentar-Kennzeichnung) verfügbar. Siehe
#
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=xml&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2024-03-20&f.datum.end=2024-03-23&f.zuordnung=BT

# %%
with open('./data/opendata_api/requestlibrary.json', 'w', encoding='utf-8') as json_file:
    json.dump(response.json(),json_file, indent=4)

# %%
with open("out_text.txt", 'w', encoding = 'utf-8') as txt_file:
    txt_file.write(response.json()['documents'][0]['text'])
