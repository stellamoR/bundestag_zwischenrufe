# %%
import requests
import pandas as pd
import json

# %%
def dict_to_html_params(data):
    html_params = ""
    for key, value in data.items():
        if value != None:
            html_params += f"&{key}={value}"
    return html_params.strip()

# %%
url_static= "https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF"
data_path = './data/protokolle/'

params = {
        "f.datum.start": "2006-11-01", # Change here for different Dates
        "f.datum.end": "2006-12-01",
        "f.zuordnung": "BT",
        "cursor" : None
    }

doc_count = 0
while(True):
    
    api_url = url_static + dict_to_html_params(params)
    print(api_url)

    response = requests.get(api_url)
    print(response)

    if response.status_code == 200:

        doc_list = response.json()['documents']
        doc_count += len(doc_list)
        for doc in doc_list:
            path = f'{data_path}{doc['wahlperiode']}_{doc['dokumentnummer'].split(r'/')[1].zfill(3)}_{doc['datum']}.json'
            print(path)
            with open(path, 'w', encoding='utf-8') as json_file:
                json.dump(doc,json_file, indent=4)
    else:
         print("Error in call. Aborting")
         break
    
    if 'cursor' not in response.json():
        print(f"Retrieved all {doc_list}Documents")
        break 
    elif response.json()['cursor']== params['cursor']:
        print(f"Retrieved all {doc_count} Documents")
        break
    else:
        params['cursor'] = response.json()['cursor']
# Out:
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2006-11-01&f.datum.end=2006-12-01&f.zuordnung=BT
# <Response [200]>
# ./data/protokolle/16_071_2006-12-01.json
# ./data/protokolle/16_070_2006-11-30.json
# ./data/protokolle/16_069_2006-11-29.json
# ./data/protokolle/16_068_2006-11-24.json
# ./data/protokolle/16_067_2006-11-23.json
# ./data/protokolle/16_066_2006-11-22.json
# ./data/protokolle/16_065_2006-11-21.json
# ./data/protokolle/16_064_2006-11-10.json
# ./data/protokolle/16_063_2006-11-09.json
# ./data/protokolle/16_062_2006-11-08.json
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=json&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2006-11-01&f.datum.end=2006-12-01&f.zuordnung=BT&cursor=AoJw-K3O444CM1BsZW5hcnByb3Rva29sbC0xMzA=
# <Response [200]>
# Retrieved all 10 Documents

# %% [markdown]
# Auch die aktuellen Protokolle sind nicht im neueren XML-Format (mit Rede + Kommentar-Kennzeichnung) verfügbar. Siehe
#
# https://search.dip.bundestag.de/api/v1/plenarprotokoll-text?format=xml&apikey=rgsaY4U.oZRQKUHdJhF9qguHMkwCGIoLaqEcaHjYLF&f.datum.start=2024-03-20&f.datum.end=2024-03-23&f.zuordnung=BT

# %%
with open('./data/opendata_api/requestlibrary.json', 'w', encoding='utf-8') as json_file:
    json.dump(response.json(),json_file, indent=4)

# %%
with open("out_text.txt", 'w', encoding = 'utf-8') as txt_file:
    txt_file.write(response.json()['documents'][0]['text'])
